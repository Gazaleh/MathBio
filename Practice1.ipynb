# %%
#make a plot of predator-prey

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(2,0.1)
y = np.sin(x*np.pi)

plt.plot(x,y)

# %%
alpha = 1
beta = 1

prey = 1
predator = 1

de_1 = prey - (alpha*predator*prey)
de_2 = -predator + (beta*predator*prey)
